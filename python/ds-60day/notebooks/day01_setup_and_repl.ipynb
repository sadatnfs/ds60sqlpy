# %% [markdown]
# # Day 1 — Python setup, REPL, virtual envs, package management
#
# Objectives:
# - Install Python 3.10+ and Jupyter.
# - Create and activate a virtual environment.
# - Use pip to install packages.
# - Launch Python REPL and Jupyter.
#
# Prerequisites: None
#
# At the end of this notebook you will be able to create a clean environment, install dependencies, and run code in Jupyter.

# %% [markdown]
# ## 1) Creating a virtual environment (reference)
#
# macOS/Linux:
# ```bash
# python3 -m venv .venv
# source .venv/bin/activate
# python -V
# ```
# Windows (PowerShell):
# ```ps1
# py -3 -m venv .venv
# .venv\Scripts\Activate.ps1
# python -V
# ```
# Install core tools:
# ```bash
# pip install --upgrade pip
# pip install jupyterlab ipykernel
# python -m ipykernel install --user --name=python3
# ```
# Launch Jupyter Lab:
# ```bash
# jupyter lab
# ```

# %% [markdown]
# ## 2) Python REPL basics
# Type `python` or `python3` in your terminal to open an interactive shell (REPL). Try some math and string operations.

# %%
1 + 1
'Hello ' + 'world'
len('data science')

# %% [markdown]
# ## 3) Your first script
# Create a file named `hello.py` with:
# ```python
# def greet(name: str) -> str:
#     return f'Hello, {name}!'
#
# if __name__ == '__main__':
#     print(greet('Data Scientist'))
# ```
# Run it with `python hello.py`.
#
# Below we reproduce similar logic in this notebook cell.

# %%
def greet(name: str) -> str:
    """Return a friendly greeting.
    Args:
        name: Person's name.
    
    Returns: greeting string.
    """
    return f'Hello, {name}!'

greet('Data Scientist')

# %% [markdown]
# ## 4) Installing a package with pip
# Use pip to install packages into your active environment:
# ```bash
# pip install numpy pandas
# ```
# Then you can import them below.

# %%
import sys, platform
print(sys.version)
print(platform.platform())

import numpy as np
import pandas as pd
np.array([1,2,3])

# %% [markdown]
# ## Exercises
# 1. Create and activate a virtual environment locally.
# 2. Install `jupyterlab`, `ipykernel`.
# 3. Create a new kernel named `python3` (done by this notebook if you ran the command).
# 4. Write a script `calc.py` that takes two numbers and prints their sum.
#
# ## Solutions (sample)
# See code cells above for references to structure functions and REPL usage.

# %% [markdown]
# ## Further reading
# - Python official docs: https://docs.python.org/3/
# - Virtual environments: https://docs.python.org/3/library/venv.html
# - JupyterLab: https://jupyterlab.readthedocs.io/

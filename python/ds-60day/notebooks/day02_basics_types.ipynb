# %% [markdown]
# # Day 2 — Basic syntax & types (str, int, float, bool)
# Objectives:
# - Variables and assignment.
# - Built-in types and conversions.
# - Basic I/O and f-strings.

# %%
# Variables and basic types
x = 42
pi = 3.14159
name = 'Ada'
is_ready = True
print(type(x), type(pi), type(name), type(is_ready))

# Casting
int('5'), float('2.7'), str(123)

# %% [markdown]
# ## Truthiness and comparisons
# Empty containers are False, non-empty True.

# %%
if []:
    print('truthy')
else:
    print('falsy')

3 < 5 < 10, 'a' < 'b'

# %% [markdown]
# ## Exercises
# 1) Read two numbers with input() and print their sum.
# 2) Given a string '  Data Science  ', trim it and lowercase it.
# 3) Convert '3.14' to float and multiply by 2.
#
# ## Solutions (sample)

# %%
s = '  Data Science  ' 
s.strip().lower()
float('3.14') * 2
